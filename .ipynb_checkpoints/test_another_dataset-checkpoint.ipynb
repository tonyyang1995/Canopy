# %%
import importlib
import utils.helper as helper
from utils.helper import read_excel
from utils.helper import draw_hex_contour_plot, show_joint_plots, draw_heatmap
import matplotlib.pyplot as plt
from utils.helper import create_cross_validation, read_csv, draw_box_plot, draw_regplots, seed_everything
import os
import numpy as np
import pandas as pd
import seaborn as sns
import pickle as pkl

# ridge_regression results
import utils.model
from utils.model import RidgeRegressionModel
from utils.model import RandomForestModel
from utils.model import SVMRegressor
from utils.model import XGBregressor
from utils.model import ANNregressor

# %%
print("step1: define args and load dataset")
excel_file_path = './Concrete_Data_Test.xlsx'
sheet_page = "Sheet1" # sheet page name
label = "Strength" # the label for the pred column
ridge_save_path = "results_test/ridge_regression_"
rf_save_path = "result_test/rf_regression"
svm_save_path = "results_test/svm_regression"
xgb_save_path = "results_test/xgb_regression"
ann_save_path = "results_test/ann_regression"

box_plot_colors = sns.color_palette("Set2")
kfold = 10
split_rate=0.1
facecolor = "#FF8C94"
patchcolor = 'red'
alpha = 0.3
# xlim = (0, 120)
# ylim = (0, 120)
xlim = None
ylim = None

df = read_excel(excel_file_path, sheet_page)
column_names = list(df.columns)
print(column_names)
save_paths = []
for feature in column_names[:8]:
    sp = draw_hex_contour_plot(df, feature, label, "#4CB391")
    save_paths.append(sp)
# Out:
# step1: define args and load dataset
# ['Cement', 'Slag', 'FlyAsh', 'Water', 'HRWR', 'CA', 'FA', 'ConcreteAge', 'Strength']

# %%
excel_file_path = './Data_Collection_V3.xlsx'
test_df = read_excel(excel_file_path, sheet_page)
test_df_select = test_df[list(df.columns)]

# %%
test_columns = list(test_df_select.columns)
x_test = test_df[test_columns[:-1]]
y_test = test_df[["Strength"]]

# %%
# 2. draw joint plots
print("step2: analysis dataset and draw plots")
row = 4
col= 2
count = 0
fig, axs = plt.subplots(row,col, figsize=(20,20))
for i in range(row):
    for j in range(col):
        show_joint_plots(save_paths[count], axs[i][j])
        count += 1
plt.tight_layout()
# plt.show()
# Out:
# step2: analysis dataset and draw plots

# %%
def draw_heatmap2(df, drop_column=None, cmap='coolwarm'):
    new_df = df.fillna(0)
    if drop_column is not None:
        new_df.drop(columns=drop_column, inplace=True)
    corr_matrix = new_df.corr()
    sns.heatmap(corr_matrix, annot=True, cmap=cmap)
# 3. draw heatmap
print("step3: drawing heatmap")
plt.close("all")
plt.figure(figsize=(15, 15))
# cmap options: ["YlGnBu", "Blues", "coolwarm", "BuPu", "Greens", "Oranges", "Reds", "Purples", "YlOrBr"]
draw_heatmap2(df, cmap='Greens')
plt.title("Heatmap")
plt.savefig('results_test/heatmap.png')
# plt.show()
# Out:
# step3: drawing heatmap

# %%
column_names = df.columns
x_train = df[column_names[:-1]]
y_train = df[[column_names[-1]]]

# %%
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
import xgboost as xgb

# %%
import importlib
import utils
importlib.reload(utils.model)
from utils.model import calculate_rmse, calculate_rmae
from utils.model import r2_score, calculate_RSR
from utils.model import calculate_mape, calcuate_nmbe

# %%
# ridge
model = linear_model.RidgeCV(alphas=np.logspace(-6, 6, 13))
model.fit(x_train, y_train)
pred = model.predict(x_test)
rmse = calculate_rmse(y_test, pred)
mae = calculate_rmae(y_test, pred)
r2 = r2_score(y_test, pred)
rsr = calculate_RSR(y_test, pred)
mape = calculate_mape(y_test, pred)
nmbe = calcuate_nmbe(y_test, pred)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /Users/tony/Desktop/Concrete_ML/Concrete_ML/utils/model.py:72: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   scale = float(np.std(actual))

# %%
print(f"rmse: {rmse}")
print(f"mae: {mae}")
print(f"r2: {r2}")
print(f"r2r: {rsr}")
print(f"mape: {mape}")
print(f"nmbe: {nmbe}")
# Out:
# rmse: 17.420399254557022
# mae: 3.7454126461481527
# r2: 0.3859794304093328
# r2r: 0.16847405472943014
# mape: 26.85905151277037
# nmbe: -21.440012345253177

# %%
# rf
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
pred = model.predict(x_test)
rmse = calculate_rmse(y_test, pred)
mae = calculate_rmae(y_test, pred)
r2 = r2_score(y_test, pred)
rsr = calculate_RSR(y_test, pred)
mape = calculate_mape(y_test, pred)
nmbe = calcuate_nmbe(y_test, pred)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /Users/tony/Desktop/Concrete_ML/Concrete_ML/utils/model.py:72: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   scale = float(np.std(actual))

# %%
print(f"rmse: {rmse}")
print(f"mae: {mae}")
print(f"r2: {r2}")
print(f"r2r: {rsr}")
print(f"mape: {mape}")
print(f"nmbe: {nmbe}")
# Out:
# rmse: 28.988853205843935
# mae: 4.718845428277887
# r2: 0.14748665068610556
# r2r: 0.2122604631457644
# mape: 44.62830400813677
# nmbe: -4402.685878823023

# %%
model = xgb.XGBRegressor(n_estimators=1000)
model.fit(x_train, y_train)
pred = model.predict(x_test)
rmse = calculate_rmse(y_test, pred)
mae = calculate_rmae(y_test, pred)
r2 = r2_score(y_test, pred)
rsr = calculate_RSR(y_test, pred)
mape = calculate_mape(y_test, pred)
nmbe = calcuate_nmbe(y_test, pred)
print(f"rmse: {rmse}")
print(f"mae: {mae}")
print(f"r2: {r2}")
print(f"r2r: {rsr}")
print(f"mape: {mape}")
print(f"nmbe: {nmbe}")
# Out:
# rmse: 28.573362162745216
# mae: 4.694268656907055
# r2: 0.19858568906784058
# r2r: 0.2111549645755974
# mape: 45.37318453748005
# nmbe: -3543.797463764853
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /Users/tony/Desktop/Concrete_ML/Concrete_ML/utils/model.py:72: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   scale = float(np.std(actual))

# %%
model = MLPRegressor(hidden_layer_sizes=(32, 128, 128), max_iter=1000, random_state=42, tol=1e-6, batch_size=64)
model.fit(x_train, y_train)
pred = model.predict(x_test)
rmse = calculate_rmse(y_test, pred)
mae = calculate_rmae(y_test, pred)
r2 = r2_score(y_test, pred)
rsr = calculate_RSR(y_test, pred)
mape = calculate_mape(y_test, pred)
nmbe = calcuate_nmbe(y_test, pred)
print(f"rmse: {rmse}")
print(f"mae: {mae}")
print(f"r2: {r2}")
print(f"r2r: {rsr}")
print(f"mape: {mape}")
print(f"nmbe: {nmbe}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1631: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# rmse: 30.66380210821255
# mae: 4.813282161590175
# r2: -0.04524005287670785
# r2r: 0.21650836341194343
# mape: 42.39653517138922
# nmbe: -6927.99709779576
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# /Users/tony/Desktop/Concrete_ML/Concrete_ML/utils/model.py:72: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   scale = float(np.std(actual))
