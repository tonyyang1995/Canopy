# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from ast import literal_eval

# %%
# draw box plot
ridge_result_path = 'results/ridge_regression/results.csv'
rf_result_path = 'results/random_forest_regression/results.csv'
svm_result_path = 'results/svm_regression/results.csv'
xgb_result_path = 'results/xgboost_regression/results.csv'
ann_result_path = 'results/ann_regression/results.csv'

# %%
def read_csv(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
ridge_results = read_csv(ridge_result_path)
rf_results = read_csv(rf_result_path)
svm_results = read_csv(svm_result_path)
xgb_results = read_csv(xgb_result_path)
ann_results = read_csv(ann_result_path)

# %%
def convert_str2_list(list_str):
    list_str = list_str[1:-1]
    list_str = ' '.join(list_str.split())
    list_str = list_str.split(" ")
    list_str = [float(a) for a in list_str]
    return list_str

# %%
colors = sns.color_palette('Set2')

# %%
def draw_relation_plot(gts, preds, ax, title=None):
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)


def draw_relation_plots(outputs, ax, title=None):
    gts = []
    preds = []
    for (gt, pred) in outputs:
        gts.extend(gt.tolist())
        preds.extend(pred.tolist())
        
    gts = np.array(gts)
    preds = np.array(preds)
    
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)

# %%
save_path = 'results/ridge_regression'
results = ridge_results
for idx in range(0, 10):
    res = results[f'{idx}_fold']
    gts, pred = res[0], res[1]
    gts = convert_str2_list(gts)
    preds = convert_str2_list(pred)
    
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    
    plt.savefig(f'{save_path}/lmplot_{idx}_fold.png')

# %%
save_path = 'results/random_forest_regression'
results = rf_results
for idx in range(0, 10):
    res = results[f'{idx}_fold']
    gts, pred = res[0], res[1]
    gts = convert_str2_list(gts)
    preds = convert_str2_list(pred)
    
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    
    plt.savefig(f'{save_path}/lmplot_{idx}_fold.png')

# %%
save_path = 'results/svm_regression'
results = svm_results
for idx in range(0, 10):
    res = results[f'{idx}_fold']
    gts, pred = res[0], res[1]
    gts = convert_str2_list(gts)
    preds = convert_str2_list(pred)
    
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    
    plt.savefig(f'{save_path}/lmplot_{idx}_fold.png')

# %%
save_path = 'results/xgboost_regression'
results = xgb_results
for idx in range(0, 10):
    res = results[f'{idx}_fold']
    gts, pred = res[0], res[1]
    gts = convert_str2_list(gts)
    preds = convert_str2_list(pred)
    
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    
    plt.savefig(f'{save_path}/lmplot_{idx}_fold.png')

# %%
save_path = 'results/ann_regression'
results = ann_results
for idx in range(0, 10):
    res = results[f'{idx}_fold']
    gts, pred = res[0], res[1]
    gts = convert_str2_list(gts)
    preds = convert_str2_list(pred)
    
    gts = np.array(gts)
    preds = np.array(preds)
    df_values = np.stack([gts, preds], axis=1)
    df = pd.DataFrame(df_values, columns=["Experiment Values (MPa)", "Prediction Values (MPa)"])
    plot = sns.lmplot(data=df, x="Experiment Values (MPa)", y="Prediction Values (MPa)", legend=True, markers=['x'], scatter_kws={"s":3})
#     plt.legend(['95% Confidence Interval'], loc='upper left', frameon=True)

    
    ax = plot.axes[0, 0]  # Get the axis from lmplot
    sns.regplot(x="Experiment Values (MPa)", y="Prediction Values (MPa)", data=df, scatter=False, ci=95, line_kws={'color':'black'}, 
            ax=ax, 
            scatter_kws={'s': 3}, 
            fit_reg=True)
    ax.collections[1].set_facecolor("#FF8C94")
    ax.collections[1].set_alpha(0.3)  # Adjust transparency if needed
    
    red_patch = mpatches.Patch(color="red", alpha=0.3, label="95% Confidence Interval")
    plt.legend(handles=[red_patch], loc='upper left', frameon=True)

    plt.tight_layout()
    plt.xlim(0, 120)
    plt.ylim(0, 120)
    
    plt.savefig(f'{save_path}/lmplot_{idx}_fold.png')
